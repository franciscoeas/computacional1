# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from pylab import *

# %%
df=pd.read_csv("/home/franciscoeas/Actividad 5/LosAngeles1.csv",parse_dates=['Date Time'],header=int(0))

# %%
df.columns
# Out:
# Index(['Date Time', ' Water Level', ' Sigma', ' O', ' F', ' R', ' L',
#        ' Quality '],
#       dtype='object')

# %%
df.head(10)
# Out:
#             Date Time   Water Level   Sigma   O   F   R   L  Quality
# 0 2016-01-01 00:00:00         0.823   0.000   0   0   0   0         v
# 1 2016-01-01 00:06:00         0.797   0.013   0   0   0   0         v
# 2 2016-01-01 00:12:00         0.773   0.017   0   0   0   0         v
# 3 2016-01-01 00:18:00         0.741   0.023   0   0   0   0         v
# 4 2016-01-01 00:24:00         0.716   0.014   0   0   0   0         v
# 5 2016-01-01 00:30:00         0.710   0.018   0   0   0   0         v
# 6 2016-01-01 00:36:00         0.700   0.015   0   0   0   0         v
# 7 2016-01-01 00:42:00         0.686   0.019   0   0   0   0         v
# 8 2016-01-01 00:48:00         0.675   0.023   0   0   0   0         v
# 9 2016-01-01 00:54:00         0.658   0.014   0   0   0   0         v

# %%
df.columns=['Date Time','Water Level','Sigma','O','F','R','L','Quality']

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Date Time      0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# dtype: int64

# %%
x=df["Date Time"]
y=df["Water Level"]

plt.title("Mareas Los Angeles,CA")
plt.ylabel('Nivel de agua (m)')
plt.xlabel('Fecha')
plt.grid(True)


plt.plot(x,y)

# %%
plt.show()
